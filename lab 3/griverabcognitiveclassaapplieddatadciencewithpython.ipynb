# %% [markdown]
# **Estudiante: Gustavo Rivera**
#
# ---
#
# **Curso: Métodos numéricos**
#
# ---
#
# **Lab 3**

# %% [markdown]
# **curso 1:**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **curso 2**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **curso 3**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
